# %% [markdown]
# <a href="https://colab.research.google.com/github/chriscabezash/TEST/blob/master/Censo_2017_Viviendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
import pandas as pd

# ID del archivo en Google Drive

#file_id = '1l-nXjqdxJatyDWVPcwKxOWWLoKhzRQFd'
file_id = '18hut4BbMh_ugu3Zp-SMJyacegSILc0Pi'

# URL del archivo
url = f'https://drive.google.com/uc?id={file_id}'

# Descargar el archivo
output = 'file.csv'
gdown.download(url, output, quiet=False)

# Leer el archivo CSV
df = pd.read_csv(output, delimiter=';')

# Mostrar el DataFrame
df
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=18hut4BbMh_ugu3Zp-SMJyacegSILc0Pi
# From (redirected): https://drive.google.com/uc?id=18hut4BbMh_ugu3Zp-SMJyacegSILc0Pi&confirm=t&uuid=47410146-34a4-4ad8-8984-b9aae1571c85
# To: /content/file.csv
# 100%|██████████| 380M/380M [00:08<00:00, 47.5MB/s]
#          REGION  PROVINCIA  COMUNA  DC  AREA  ZC_LOC  ID_ZONA_LOC  NVIV  P01  \
# 0            15        152   15202   1     2       6        13225     1    3
# 1            15        152   15202   1     2       6        13225     2    1
# 2            15        152   15202   1     2       6        13225     3    1
# 3            15        152   15202   1     2       6        13225     4    1
# 4            15        152   15202   1     2       6        13225     5    3
# ...         ...        ...     ...  ..   ...     ...          ...   ...  ...
# 6499569       1         11    1101  99     1     999        12486   232    1
# ...

# %%
df.describe()
# Out:
#              REGION     PROVINCIA        COMUNA            DC          AREA  \
# count  6.499574e+06  6.499574e+06  6.499574e+06  6.499574e+06  6.499574e+06
# mean   9.387927e+00  9.580448e+01  9.587300e+03  6.851055e+00  1.148535e+00
# std    3.953171e+00  3.923588e+01  3.926389e+03  7.617056e+00  3.556294e-01
# min    1.000000e+00  1.100000e+01  1.101000e+03  1.000000e+00  1.000000e+00
# 25%    6.000000e+00  6.100000e+01  6.102000e+03  2.000000e+00  1.000000e+00
# 50%    9.000000e+00  9.200000e+01  9.211000e+03  5.000000e+00  1.000000e+00
# 75%    1.300000e+01  1.310000e+02  1.312000e+04  9.000000e+00  1.000000e+00
# max    1.600000e+01  1.630000e+02  1.630500e+04  9.900000e+01  2.000000e+00
#
#              ZC_LOC   ID_ZONA_LOC          NVIV           P01           P02  \
# count  6.499574e+06  6.499574e+06  6.499574e+06  6.499574e+06  6.499574e+06
# mean   1.262980e+01  7.984414e+03  6.038110e+02  1.301122e+00  1.306294e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6499574 entries, 0 to 6499573
# Data columns (total 20 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   REGION         int64
#  1   PROVINCIA      int64
#  2   COMUNA         int64
#  3   DC             int64
#  4   AREA           int64
#  5   ZC_LOC         int64
#  6   ID_ZONA_LOC    int64
#  7   NVIV           int64
#  8   P01            int64
#  9   P02            int64
#  10  P03A           int64
#  11  P03B           int64
#  12  P03C           int64
#  13  P04            int64
#  14  P05            int64
#  15  CANT_HOG       int64
#  16  CANT_PER       int64
#  17  REGION_15R     int64
#  18  PROVINCIA_15R  int64
#  19  COMUNA_15R     int64
# dtypes: int64(20)
# memory usage: 991.8 MB
